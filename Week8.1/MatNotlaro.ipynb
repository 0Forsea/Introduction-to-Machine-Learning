# %%
import pandas as pd

# %%
veri=pd.read_csv('student-mat.csv',sep=';')

# %%
veri=veri[['G1','G2','G3','studytime','failures','absences','age']]

# %%
veri.head(100)
# Out:
#     G1  G2  G3  studytime  failures  absences  age
# 0    5   6   6          2         0         6   18
# 1    5   5   6          2         0         4   17
# 2    7   8  10          2         3        10   15
# 3   15  14  15          3         0         2   15
# 4    6  10  10          2         0         4   16
# ..  ..  ..  ..        ...       ...       ...  ...
# 95   7  10  10          4         1         2   15
# 96  11  15  15          1         0         2   16
# 97   8   9  10          2         0         2   16
# 98  11  14  14          1         0         6   16
# 99   7   9   8          3         0         0   16
#
# [100 rows x 7 columns]

# %%
veri.rename(columns={'G1':'Not1',
                    'G2':'Not2',
                    'G3':'Final',},inplace=True)
veri.head()
# Out:
#    Not1  Not2  Final  studytime  failures  absences  age
# 0     5     6      6          2         0         6   18
# 1     5     5      6          2         0         4   17
# 2     7     8     10          2         3        10   15
# 3    15    14     15          3         0         2   15
# 4     6    10     10          2         0         4   16

# %%
import numpy as np
y=np.array(veri['Final'])
X=np.array(veri.drop('Final',axis=1))

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.score(X_train,y_train))
print(lr.score(X_test,y_test))
veri.head()
# Out:
# 0.8261275475197141
# 0.8325898318712225
#    Not1  Not2  Final  studytime  failures  absences  age
# 0     5     6      6          2         0         6   18
# 1     5     5      6          2         0         4   17
# 2     7     8     10          2         3        10   15
# 3    15    14     15          3         0         2   15
# 4     6    10     10          2         0         4   16

# %%
yeni_veri=np.array([[10,15,0,0,15,18]])
lr.predict(yeni_veri)
# Out:
# array([14.80090017])
